# %%
from google.oauth2 import service_account
import os
import yaml
import git

from dataclasses import dataclass


path = os.path.expanduser('~')

def get_git_root(path):
    
        git_repo = git.Repo(path, search_parent_directories=True)
        git_root = git_repo.git.rev_parse("--show-toplevel")
        return (git_root)
    
##def return_git_path():
    
git_path = get_git_root(os.getcwd())


## profile vars

@dataclass
class IdentifyConfigVariables:
    
    path_source: str
    directory_path: str
    full_path: str

def load_droughty_profile():

    IdentifyConfigVariables.path_source = 'local_vars'

    path = os.path.expanduser('~')

    profile_pass = os.path.join(path,".droughty/profile.yaml")

    with open(profile_pass) as f:
        droughty_profile = yaml.load(f, Loader=yaml.FullLoader)

    return droughty_profile

def load_droughty_project():

    filename = 'droughty_project.yaml'

    droughty_project = os.path.join(git_path,filename)

    with open(droughty_project) as f:
        droughty_project = yaml.load(f, Loader=yaml.FullLoader)

    return droughty_project

droughty_profile = load_droughty_profile()

droughty_project = load_droughty_project()

@dataclass
class ProjectVariables:
    
    environment_profile: str
    warehouse: str
    schema: str
    test_schemas: str

    role: str
    password: str
    database: str
        
def assign_project_variables():

    for key, value in droughty_project.items():

        if key == 'profile':

            if value in droughty_profile:

                ## global vars

                if IdentifyConfigVariables.path_source == 'local_vars':

                    ProjectVariables.warehouse =  droughty_profile[value]['warehouse_name']
                    ProjectVariables.schema = droughty_profile[value]['schema_name']
                    ExploresVariables.test_schemas = droughty_profile[value]['test_schemas']   

droughty_project_variables = assign_project_variables()

# %%
print (IdentifyConfigVariables.path_source)
# Out:
# local_vars

# %%
print (ProjectVariables.warehouse)
# Out:
# big_query

# %%
for key,value in droughty_project.items():

    if key == 'profile':

        if value in droughty_profile:

            ## global vars

            if path_source == 'local_vars':

                warehouse_name =  droughty_profile[value]['warehouse_name']
                schema_name = droughty_profile[value]['schema_name']
                test_schemas = droughty_profile[value]['test_schemas']

            elif path_source == 'external_vars':

                warehouse_name =  os.environ.get("BIG_QUERY_WAREHOUSE_NAME")
                schema_name = os.environ.get('BIG_QUERY_DATASET_DEV')
                test_schemas = lookml_config[value]['test_schemas']


            environment_profile = environment_project['profile']

            if path_source == 'local_vars':

                if warehouse_name == 'big_query':

                    ## bigquery vars

                    project_name =  droughty_profile[value]['project_name']

                    service_account_path = droughty_profile[value]['key_file']
                    service_account = service_account.Credentials.from_service_account_file(
                        service_account_path,
                    )

                elif warehouse_name == 'snowflake':

                    ## snowflake vars

                    project_name = ['']
                    snowflake_account = droughty_profile[value]['account']
                    snowflake_user = droughty_profile[value]['user']
                    snowflake_schema = droughty_profile[value]['schema_name']
                    snowflake_database = droughty_profile[value]['database']
                    snowflake_password = droughty_profile[value]['password']
                    snowflake_warehouse = droughty_profile[value]['warehouse']
                    snowflake_role = droughty_profile[value]['role']

            elif path_source == 'external_vars':


                ## bigquery vars

                if warehouse_name == 'big_query':

                    project_name =   os.environ.get('BIG_QUERY_PROJECT_DEV')

                    service_account_path = "./droughty-service-account.json"
                    service_account = service_account.Credentials.from_service_account_file(
                        service_account_path,
                    )

                ## snowflake vars

                elif warehouse_name == 'snowflake':

                    project_name = ['']
                    snowflake_account = os.environ.get('SNOWFLAKE_ACCOUNT')
                    snowflake_user = os.environ.get('SNOWFLAKE_USER')
                    snowflake_schema = os.environ.get('SNOWFLAKE_SCHEMA_NAME')
                    snowflake_database = os.environ.get('SNOWFLAKE_DATABASE')
                    snowflake_password = os.environ.get('SNOWFLAKE_PASSWORD')
                    snowflake_warehouse = os.environ.get('SNOWFLAKE_WAREHOUSE')
                    snowflake_role = os.environ.get('SNOWFLAKE_ROLE')

# %%
git_path

# %%
print(IdentifyProjectVariables.warehouse)

# %%
t1 = assign_project_variables()

# %%
environment_project = load_droughty_project()

# %%
print(environment_project)

# %%
@dataclass
class Robot:
    
    name: str
    color: str
    weight: int

    def introduce_self(introduction):
        print("My name is " + introduction.name)

@dataclass
class Person:

    name: str
    personality: str
    isSitting: str

    def sit_down(self):
        print("My name is " + self.name)


r1 = Robot("Tom", "red", 30)
r2 = Robot("Jerry", "blue", 40)

p1 = Person("Alice", "aggressive", False)
p2 = Person("Becky", "aggressive", True)

p1.robot_owned = r2
p2.robot_owned = r1


p1.robot_owned.introduce_self()

# %%
from dataclasses import dataclass

@dataclass
class Person:
    name: str
    town: str
    age: int

p = Person('John Doe', 'Eastbourne', 34)
print(p)

# %%
from dataclasses import dataclass
@dataclass
class Robot:
    name: str
    color: str
    weight: int
    age: int
        
##r1.age = 1000  
r1 = Robot("Tom", "red", 30,"")
r1.age = 2000

print (r1)
print (r1.name)
