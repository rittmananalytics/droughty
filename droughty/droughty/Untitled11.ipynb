# %%
import lkml as looker
from pprint import pprint
from google.oauth2 import service_account
import pandas_gbq
from contextlib import redirect_stdout
import snowflake.connector
from sqlalchemy import create_engine
from snowflake.sqlalchemy import URL
import pandas as pd
import pandas
import os
import json
import sys
import yaml
import git

from lookml_base_dict import d1
from lookml_base_dict import explore_df


def get_all_values(nested_dictionary):

    
    for key,value in nested_dictionary.items():

        explore = {


            "explore": key,
                
            "view_name": key
                
            }
            
        
        yield(looker.dump(explore))
        
        
        for key,value in value.items():

            join = {


                "table": value,

                "sql_table_name": value

                }

            yield(looker.dump(join))


nested_dictionary = explore_df     

get_all_values(nested_dictionary)

def get_git_root(path):

        git_repo = git.Repo(path, search_parent_directories=True)
        git_root = git_repo.git.rev_parse("--show-toplevel")
        return (git_root)

git_def_path = get_git_root(os.getcwd())

def explore_output():
    
    git_path = git_def_path

    rel_path = "base"

    path = os.path.join(git_path, rel_path)

    if not os.path.exists(path):
        os.makedirs(path)
        
    filename = '_explore.layer.lkml'

    with open(os.path.join(path, filename), 'w') as file:

        with redirect_stdout(file):

                for value in get_all_values(integration_layer):

                    print(value)

explore_output()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <module>
#      82                 for value in get_all_values(integration_layer):
#      84                     print(value)
# ---> 86 explore_output()
#
# Input In [20], in explore_output()
#      78 with open(os.path.join(path, filename), 'w') as file:
#      80     with redirect_stdout(file):
# ---> 82             for value in get_all_values(integration_layer):
#      84                 print(value)
#
# Input In [20], in get_all_values(nested_dictionary)
#      39 for key,value in value.items():
#      41     join = {
#      42
#      43
#    (...)
#      47
#      48         }
# ---> 50     yield(looker.dump(join))
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/lkml/__init__.py:68, in dump(obj, file_object)
#      57 """Serialize a Python dictionary into LookML.
#      58
# ...

# %%
nested_dictionary
# Out:
#          table_catalog  table_schema               table_name  \
# 0    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 1    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 2    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 3    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 4    client-kaplan-poc  analytics_qa  sales_quota_allocations
# ..                 ...           ...                      ...
# 434  client-kaplan-poc  analytics_qa    targets_sales_regions
# 435  client-kaplan-poc  analytics_qa    targets_sales_regions
# 436  client-kaplan-poc  analytics_qa    targets_sales_regions
# 437  client-kaplan-poc  analytics_qa    targets_sales_regions
# 438  client-kaplan-poc  analytics_qa    targets_sales_regions
#
#              column_name           field_path data_type  \
# 0    quota_allocation_pk  quota_allocation_pk    STRING
# 1        university_code      university_code    STRING
# ...

# %%
print(get_all_values(nested_dictionary))
# Out:
# <generator object get_all_values at 0x13073b430>

# %%
import lkml as looker
from pprint import pprint
from google.oauth2 import service_account
import pandas_gbq
from contextlib import redirect_stdout
import snowflake.connector
from sqlalchemy import create_engine
from snowflake.sqlalchemy import URL
import pandas as pd
import pandas
import os
import json
import sys
import yaml
import git

from lookml_base_dict import d1
from lookml_base_dict import explore_df

# %%
explore_df
# Out:
#          table_catalog  table_schema               table_name  \
# 0    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 1    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 2    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 3    client-kaplan-poc  analytics_qa  sales_quota_allocations
# 4    client-kaplan-poc  analytics_qa  sales_quota_allocations
# ..                 ...           ...                      ...
# 434  client-kaplan-poc  analytics_qa    targets_sales_regions
# 435  client-kaplan-poc  analytics_qa    targets_sales_regions
# 436  client-kaplan-poc  analytics_qa    targets_sales_regions
# 437  client-kaplan-poc  analytics_qa    targets_sales_regions
# 438  client-kaplan-poc  analytics_qa    targets_sales_regions
#
#              column_name           field_path data_type  \
# 0    quota_allocation_pk  quota_allocation_pk    STRING
# 1        university_code      university_code    STRING
# ...

# %%
d1
# Out:
# {'budgets_sales': {('budget_pk', 'string', 'not available'): {},
#   ('institution_fk', 'string', 'not available'): {},
#   ('budget_group', 'string', 'not available'): {},
#   ('budget_name', 'string', 'not available'): {},
#   ('intake_name', 'string', 'not available'): {},
#   ('institution_name', 'string', 'not available'): {},
#   ('entry_type_code', 'string', 'not available'): {},
#   ('sales_region_group', 'string', 'not available'): {},
#   ('budget_amt', 'number', 'not available'): {}},
#  'core_agents': {('agent_pk', 'string', 'The key and link to an agent'): {},
#   ('country_fk', 'string', 'The key and link to a country'): {},
#   ('agent_natural_key',
#    'number',
#    'The key and link to an agent from a record'): {},
#   ('agent_salesforce_business_key',
#    'string',
#    'The key and link to an agent based salesforce record'): {},
#   ('country_natural_key',
#    'number',
#    'The key and link to a country from a record'): {},
# ...
