# %%
from transformers import pipeline

# %%
import pandas as pd
# Load the data from the path
data_path = "/Users/lewischarlesbaker/Downloads/test_columns - Sheet1.csv"
news_data = pd.read_csv(data_path, error_bad_lines=False)




# Show data information
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   column_name  13 non-null     object
# dtypes: object(1)
# memory usage: 232.0+ bytes

# %%
summarizer = pipeline("summarization")
summarized = summarizer(to_tokenize, min_length=75, max_length=300)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/transformers/configuration_utils.py:614, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     612 try:
#     613     # Load from local folder or from cache or download from model Hub and cache
# --> 614     resolved_config_file = cached_file(
#     615         pretrained_model_name_or_path,
#     616         configuration_file,
#     617         cache_dir=cache_dir,
#     618         force_download=force_download,
#     619         proxies=proxies,
#     620         resume_download=resume_download,
#     621         local_files_only=local_files_only,
#     622         use_auth_token=use_auth_token,
#     623         user_agent=user_agent,
#     624         revision=revision,
#     625         subfolder=subfolder,
#     626         _commit_hash=commit_hash,
#     627     )
#     628     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/transformers/utils/hub.py:409, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     407 try:
#     408     # Load from URL or cache if already cached
# --> 409     resolved_file = hf_hub_download(
#     410         path_or_repo_id,
#     411         filename,
#     412         subfolder=None if len(subfolder) == 0 else subfolder,
#     413         revision=revision,
#     414         cache_dir=cache_dir,
#     415         user_agent=user_agent,
#     416         force_download=force_download,
#     417         proxies=proxies,
#     418         resume_download=resume_download,
#     419         use_auth_token=use_auth_token,
#     420         local_files_only=local_files_only,
#     421     )
#     423 except RepositoryNotFoundError:
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/huggingface_hub/utils/_validators.py:124, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     120     kwargs = smoothly_deprecate_use_auth_token(
#     121         fn_name=fn.__name__, has_token=has_token, kwargs=kwargs
#     122     )
# --> 124 return fn(*args, **kwargs)
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/huggingface_hub/file_download.py:1242, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1240     logger.info("downloading %s to %s", url, temp_file.name)
# -> 1242     http_get(
#    1243         url_to_download,
#    1244         temp_file,
#    1245         proxies=proxies,
#    1246         resume_size=resume_size,
#    1247         headers=headers,
#    1248     )
#    1250 logger.info("storing %s in cache at %s", url, blob_path)
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/huggingface_hub/file_download.py:487, in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries)
#     486 total = resume_size + int(content_length) if content_length is not None else None
# --> 487 progress = tqdm(
#     488     unit="B",
#     489     unit_scale=True,
#     490     total=total,
#     491     initial=resume_size,
#     492     desc="Downloading",
#     493     disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     494 )
#     495 for chunk in r.iter_content(chunk_size=1024):
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/huggingface_hub/utils/tqdm.py:120, in tqdm.__init__(self, *args, **kwargs)
#     119     kwargs["disable"] = True
# --> 120 super().__init__(*args, **kwargs)
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/tqdm/notebook.py:242, in tqdm_notebook.__init__(self, *args, **kwargs)
#     241 total = self.total * unit_scale if self.total else self.total
# --> 242 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243 self.container.pbar = proxy(self)
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/tqdm/notebook.py:115, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     114 if IProgress is None:  # #187 #451 #558 #872
# --> 115     raise ImportError(
#     116         "IProgress not found. Please update jupyter and ipywidgets."
#     117         " See https://ipywidgets.readthedocs.io/en/stable"
#     118         "/user_install.html")
#     119 if total:
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 summarizer = pipeline("summarization")
#       2 summarized = summarizer(to_tokenize, min_length=75, max_length=300)
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/transformers/pipelines/__init__.py:700, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     694     logger.warning(
#     695         f"No model was supplied, defaulted to {model} and revision"
#     696         f" {revision} ({HUGGINGFACE_CO_RESOLVE_ENDPOINT}/{model}).\n"
#     697         "Using a pipeline without specifying a model name and revision in production is not recommended."
#     698     )
#     699     if config is None and isinstance(model, str):
# --> 700         config = AutoConfig.from_pretrained(model, _from_pipeline=task, **hub_kwargs, **model_kwargs)
#     701         hub_kwargs["_commit_hash"] = config._commit_hash
#     703 if device_map is not None:
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/transformers/models/auto/configuration_auto.py:809, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     807 kwargs["name_or_path"] = pretrained_model_name_or_path
#     808 trust_remote_code = kwargs.pop("trust_remote_code", False)
# --> 809 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     810 if "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]:
#     811     if not trust_remote_code:
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/transformers/configuration_utils.py:559, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     557 original_kwargs = copy.deepcopy(kwargs)
#     558 # Get config dict associated with the base config file
# --> 559 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     560 if "_commit_hash" in config_dict:
#     561     original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# File ~/.virtualenvs/droughty_dev_0.1.0/lib/python3.8/site-packages/transformers/configuration_utils.py:635, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     632         raise
#     633     except Exception:
#     634         # For any other exception, we throw a generic error.
# --> 635         raise EnvironmentError(
#     636             f"Can't load the configuration of '{pretrained_model_name_or_path}'. If you were trying to load it"
#     637             " from 'https://huggingface.co/models', make sure you don't have a local directory with the same"
#     638             f" name. Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a directory"
#     639             f" containing a {configuration_file} file"
#     640         )
#     642 try:
#     643     # Load config dict
#     644     config_dict = cls._dict_from_json_file(resolved_config_file)
#
# OSError: Can't load the configuration of 'sshleifer/distilbart-cnn-12-6'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'sshleifer/distilbart-cnn-12-6' is the correct path to a directory containing a config.json file
